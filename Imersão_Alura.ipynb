# %% [markdown]
# <a href="https://colab.research.google.com/github/cauancalmeida/Portefolio/blob/main/Imers%C3%A3o_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #Analise de dados

# %% [markdown]
# Palavra da aula: Pandas

# %%
df= pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv") #importação dos dados

# %% [markdown]
# ##Visualisação Inicial dos dados

# %%
df.head() #exibe as 5 primeiras linhas
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               AU            M
# 3               AU            M
# 4               US            M

# %%
df.info() #exibe informações gerais do df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe() #descreve como estão destribuidos os dados numericos
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape #df.shape[0],df.shape[1]
print(f"O DataFrame possui {linhas} linhas e {colunas} colunas.")
# Out:
# O DataFrame possui 133349 linhas e 11 colunas.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Mapeamento dos nomes das colunas para português
mapeamento_colunas = {
    'work_year': 'ano',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'salario_dolar',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'tamanho_empresa'
}

# Renomear as colunas do DataFrame
df.rename(columns=mapeamento_colunas, inplace=True)

# Exibir os novos nomes das colunas para verificar
print(df.columns)
# Out:
# Index(['ano', 'nivel_experiencia', 'contrato', 'cargo', 'salario', 'moeda',
#        'salario_dolar', 'residencia', 'remoto', 'localizacao_empresa',
#        'tamanho_empresa'],
#       dtype='object')

# %% [markdown]
# ##Analizando colunas categoricas

# %%
df['nivel_experiencia'].value_counts() #frequencia de cada nivel de experiencia
# Out:
# nivel_experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %% [markdown]
# Sigla	Significado	Descrição:
#
# SE | Senior	Profissional experiente (nível sênior)
#
# MI | Mid	Nível intermediário
#
# EN | Entry	Iniciante ou júnior (entry-level)
#
# EX | Executive	Executivo, liderança sênior (C-Level)

# %%
df['contrato'].value_counts() #frequencia de cada tipo de contrato
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %% [markdown]
# Sigla	Significado	Descrição
#
# FT - Full-time	Tempo integral – trabalho padrão de 40h/semana ou período completo
#
# PT - Part-time	Meio período – carga horária reduzida
#
# CT - Contract	Contrato temporário ou por projeto – geralmente por prazo determinado
#
# FL - Freelance	Freelancer – trabalho autônomo ou por demanda, sem vínculo formal

# %%
df['remoto'].value_counts() #frequencia de cada tipo de modelo de trabalho
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %% [markdown]
# Sigla - Significado
#
# 0 - Presencial
#
# 100	- Remoto
#
# 50	- Híbrido

# %%
df['tamanho_empresa'].value_counts() #frequencia do tamanho da empresa
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %% [markdown]
# Sigla - Significado - Descrição
#
# M	- Medium	- Empresa de tamanho médio
#
# L	- Large	- Empresa de tamanho grande
#
# S	- Small	- Empresa de tamanho pequeno

# %%
# Mapeamento para 'nivel_experiencia'
mapeamento_nivel_experiencia = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}
df['nivel_experiencia'] = df['nivel_experiencia'].replace(mapeamento_nivel_experiencia)
print("Frequência de cada nível de experiência:")
display(df['nivel_experiencia'].value_counts())
# Out:
# Frequência de cada nível de experiência:
# nivel_experiencia
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
# Mapeamento para 'contrato'
mapeamento_contrato = {
    'FT': 'Integral',
    'PT': 'Parcial',
    'CT': 'Contrato',
    'FL': 'Freelance'
}
df['contrato'] = df['contrato'].replace(mapeamento_contrato)
print("Frequência de cada tipo de contrato:")
display(df['contrato'].value_counts())
# Out:
# Frequência de cada tipo de contrato:
# contrato
# Integral     132563
# Contrato        394
# Parcial         376
# Freelance        16
# Name: count, dtype: int64

# %%
# Mapeamento para 'remoto'
mapeamento_remoto = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
}
df['remoto'] = df['remoto'].replace(mapeamento_remoto)
print("Frequência de cada tipo de modelo de trabalho:")
display(df['remoto'].value_counts())
# Out:
# Frequência de cada tipo de modelo de trabalho:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
# Mapeamento para 'tamanho_empresa'
mapeamento_tamanho_empresa = {
    'M': 'Media',
    'L': 'Grande',
    'S': 'Pequena'
}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(mapeamento_tamanho_empresa)
print("Frequência do tamanho da empresa:")
display(df['tamanho_empresa'].value_counts())
# Out:
# Frequência do tamanho da empresa:
# tamanho_empresa
# Media      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano nivel_experiencia  contrato               cargo  salario moeda  \
# 0  2025.0            Senior  Integral  Solutions Engineer   214000   USD
# 1  2025.0            Senior  Integral  Solutions Engineer   136000   USD
# 2  2025.0             Pleno  Integral       Data Engineer   158800   USD
# 3  2025.0             Pleno  Integral       Data Engineer   139200   USD
# 4  2025.0            Junior  Integral       Data Engineer    90000   USD
#
#    salario_dolar residencia      remoto localizacao_empresa tamanho_empresa
# 0         214000         US      Remoto                  US           Media
# 1         136000         US      Remoto                  US           Media
# 2         158800         AU  Presencial                  AU           Media
# 3         139200         AU  Presencial                  AU           Media
# 4          90000         US  Presencial                  US           Media

# %%
df.describe(include='object') #inclui os dados descritivos
# Out:
#        nivel_experiencia  contrato           cargo   moeda residencia  \
# count             133349    133349          133349  133349     133349
# unique                 4         4             390      26        102
# top               Senior  Integral  Data Scientist     USD         US
# freq               77241    132563           17314  126140     119579
#
#             remoto localizacao_empresa tamanho_empresa
# count       133349              133349          133349
# unique           3                  95               3
# top     Presencial                  US           Media
# freq        105312              119641          129561

# %% [markdown]
# ##Desafio
# 1-Utilize o método value_counts() para descobrir a frequência de cada nível de experiência na base de dados.
#
# 2- Crie um gráfico de barras que mostre a distribuição dos salários médios por nível de experiência. Para isso, você pode usar a biblioteca Matplotlib ou Seaborn.
#
# 3-Por fim, faça uma breve análise sobre o que os resultados mostram em relação aos salários por nível de experiência.

# %%
#1
df.nivel_experiencia.value_counts()
# Out:
# nivel_experiencia
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
#2
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular a média dos salários por nível de experiência
salario_medio = df.groupby('nivel_experiencia')['salario_dolar'].mean().reset_index()

#criar grafico
plt.figure(figsize=(10, 6))
sns.barplot(x='nivel_experiencia', y='salario_dolar', data=salario_medio)
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário Médio')
plt.title('Distribuição de Salários por Nível de Experiência')
plt.show()

# %% [markdown]
# 3- Este grafico nos mostra que quanto maior o nivel de experiencia, maior o salario.
# Devivo a pouca experiencia, profissionais de nivel Junior, possuem os salarios mais baixos.
# Ja quando olhamos para nivel Pleno, vemos um aumento significativo em relação aos Juniors.
# Como os profissionais seniors, ja tem uma vasta experiencia, tendem a ter os salarios mais altos quando falamos de cargos tecnicos.
# Ja como de praxe no mercado, os Executivos, mesmo sendo um menor numero absoluto, tem os maiores salarios medios.

# %% [markdown]
# #Limpeza de dados

# %% [markdown]
# Palavra chave: PRINT

# %%
df.isnull()
# Out:
#           ano  nivel_experiencia  contrato  cargo  salario  moeda  \
# 0       False              False     False  False    False  False
# 1       False              False     False  False    False  False
# 2       False              False     False  False    False  False
# 3       False              False     False  False    False  False
# 4       False              False     False  False    False  False
# ...       ...                ...       ...    ...      ...    ...
# 133344  False              False     False  False    False  False
# 133345  False              False     False  False    False  False
# 133346  False              False     False  False    False  False
# 133347  False              False     False  False    False  False
# 133348  False              False     False  False    False  False
#
#         salario_dolar  residencia  remoto  localizacao_empresa  \
# 0               False       False   False                False
# 1               False       False   False                False
# 2               False       False   False                False
# 3               False       False   False                False
# 4               False       False   False                False
# ...               ...         ...     ...                  ...
# 133344          False       False   False                False
# 133345          False       False   False                False
# 133346          False       False   False                False
# 133347          False       False   False                False
# 133348          False       False   False                False
#
#         tamanho_empresa
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 133344            False
# 133345            False
# 133346            False
# 133347            False
# 133348            False
#
# [133349 rows x 11 columns]

# %%
df.head()
# Out:
#       ano nivel_experiencia  contrato               cargo  salario moeda  \
# 0  2025.0            Senior  Integral  Solutions Engineer   214000   USD
# 1  2025.0            Senior  Integral  Solutions Engineer   136000   USD
# 2  2025.0             Pleno  Integral       Data Engineer   158800   USD
# 3  2025.0             Pleno  Integral       Data Engineer   139200   USD
# 4  2025.0            Junior  Integral       Data Engineer    90000   USD
#
#    salario_dolar residencia      remoto localizacao_empresa tamanho_empresa
# 0         214000         US      Remoto                  US           Media
# 1         136000         US      Remoto                  US           Media
# 2         158800         AU  Presencial                  AU           Media
# 3         139200         AU  Presencial                  AU           Media
# 4          90000         US  Presencial                  US           Media

# %%
df.isnull().sum() #soma dos campos nulos
# Out:
# ano                    10
# nivel_experiencia       0
# contrato                0
# cargo                   0
# salario                 0
# moeda                   0
# salario_dolar           0
# residencia              0
# remoto                  0
# localizacao_empresa     0
# tamanho_empresa         0
# dtype: int64

# %%
df['ano'].unique()#veirificando os valores unicos da coluna ano
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]#trazebdi as linhas que o ano esta nulo
# Out:
#         ano nivel_experiencia  contrato                      cargo  salario  \
# 5588    NaN            Senior  Integral            Product Manager   184500
# 59692   NaN             Pleno  Integral                   Engineer   110000
# 59710   NaN            Junior  Integral             Data Scientist   208800
# 59759   NaN            Senior  Integral          Software Engineer   135000
# 59789   NaN            Senior  Integral                   Engineer   112000
# 131000  NaN            Senior  Integral  Machine Learning Engineer   163800
# 131006  NaN            Senior  Integral     Data Analytics Manager   204500
# 133054  NaN            Junior  Integral             Data Scientist    40000
# 133281  NaN             Pleno  Integral  Machine Learning Engineer   180000
# 133317  NaN             Pleno  Integral             Data Scientist   130000
#
#        moeda  salario_dolar residencia      remoto localizacao_empresa  \
# 5588     USD         184500         US  Presencial                  US
# 59692    USD         110000         DE  Presencial                  DE
# 59710    USD         208800         US  Presencial                  US
# 59759    USD         135000         US  Presencial                  US
# 59789    USD         112000         US  Presencial                  US
# 131000   USD         163800         US  Presencial                  US
# 131006   USD         204500         US  Presencial                  US
# 133054   USD          40000         JP      Remoto                  MY
# 133281   PLN          46597         PL      Remoto                  PL
# 133317   USD         130000         US     Híbrido                  US
#
#        tamanho_empresa
# 5588             Media
# 59692            Media
# 59710            Media
# 59759            Media
# 59789            Media
# 131000           Media
# 131006           Media
# 133054          Grande
# 133281          Grande
# 133317          Grande

# %%
df_limpo = df.dropna(subset=['ano']) #exclui as linhas que possuem ano nulo

# %%
df_limpo.isnull().sum()
# Out:
# ano                    0
# nivel_experiencia      0
# contrato               0
# cargo                  0
# salario                0
# moeda                  0
# salario_dolar          0
# residencia             0
# remoto                 0
# localizacao_empresa    0
# tamanho_empresa        0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano nivel_experiencia  contrato               cargo  salario moeda  \
# 0  2025.0            Senior  Integral  Solutions Engineer   214000   USD
# 1  2025.0            Senior  Integral  Solutions Engineer   136000   USD
# 2  2025.0             Pleno  Integral       Data Engineer   158800   USD
# 3  2025.0             Pleno  Integral       Data Engineer   139200   USD
# 4  2025.0            Junior  Integral       Data Engineer    90000   USD
#
#    salario_dolar residencia      remoto localizacao_empresa tamanho_empresa
# 0         214000         US      Remoto                  US           Media
# 1         136000         US      Remoto                  US           Media
# 2         158800         AU  Presencial                  AU           Media
# 3         139200         AU  Presencial                  AU           Media
# 4          90000         US  Presencial                  US           Media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ano                  133339 non-null  float64
#  1   nivel_experiencia    133339 non-null  object
#  2   contrato             133339 non-null  object
#  3   cargo                133339 non-null  object
#  4   salario              133339 non-null  int64
#  5   moeda                133339 non-null  object
#  6   salario_dolar        133339 non-null  int64
#  7   residencia           133339 non-null  object
#  8   remoto               133339 non-null  object
#  9   localizacao_empresa  133339 non-null  object
#  10  tamanho_empresa      133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano=df_limpo['ano'].astype('int64')) #converte a coluna ano para int

# %% [markdown]
# ##Exemplo pra completar base

# %%
#Cria Datafame de teste
df_salarios = pd.DataFrame(
    {
        'Nome': ['Alice', 'Pedro', 'Charlie', 'David','Felpe','Roberto'],
        'Salario': [50000, 60000, np.nan, 55000, np.nan,1000000]
    }
)
#substitui os nulos pela media
df_salarios['Salario_Media']= df_salarios['Salario'].fillna(df_salarios['Salario'].mean().round(2))

#substitui os nulos pela mediana
df_salarios['Salario_Mediana']= df_salarios['Salario'].fillna(df_salarios['Salario'].median())

df_salarios
# Out:
#       Nome    Salario  Salario_Media  Salario_Mediana
# 0    Alice    50000.0        50000.0          50000.0
# 1    Pedro    60000.0        60000.0          60000.0
# 2  Charlie        NaN       291250.0          57500.0
# 3    David    55000.0        55000.0          55000.0
# 4    Felpe        NaN       291250.0          57500.0
# 5  Roberto  1000000.0      1000000.0        1000000.0

# %%
#cria df de teste
df_temperatura = pd.DataFrame({
    'Dia': ['Segunda','Terça','Quarta','Quinta','Sexta'],
    "Temp": [30,np.nan,25,30,np.nan]
})
#preenchendo os valores nulos com os valores do dia anterior
df_temperatura['Preechido_ffill'] = df_temperatura['Temp'].ffill()
df_temperatura
# Out:
#        Dia  Temp  Preechido_ffill
# 0  Segunda  30.0             30.0
# 1    Terça   NaN             30.0
# 2   Quarta  25.0             25.0
# 3   Quinta  30.0             30.0
# 4    Sexta   NaN             30.0

# %%
#cria df de teste
df_temperatura = pd.DataFrame({
    'Dia': ['Segunda','Terça','Quarta','Quinta','Sexta'],
    "Temp": [30,np.nan,25,30,np.nan]
})
#preenchendo os valores nulos com os valores do dia posterior
df_temperatura['Preechido_bfill'] = df_temperatura['Temp'].bfill()
df_temperatura
# Out:
#        Dia  Temp  Preechido_bfill
# 0  Segunda  30.0             30.0
# 1    Terça   NaN             25.0
# 2   Quarta  25.0             25.0
# 3   Quinta  30.0             30.0
# 4    Sexta   NaN              NaN

# %%
#cria df de teste
df_cidades = pd.DataFrame({
    'Nome': ['Alice', 'Pedro', 'Charlie', 'David','Felpe','Roberto'],
    "Cidade": ['São Paulo',np.nan,'Curitiba','Belo Horizonte',np.nan,'Manaus']
})
df_cidades['Cidade_preenchida'] = df_cidades['Cidade'].fillna('Desconhecida')
df_cidades
# Out:
#       Nome          Cidade Cidade_preenchida
# 0    Alice       São Paulo         São Paulo
# 1    Pedro             NaN      Desconhecida
# 2  Charlie        Curitiba          Curitiba
# 3    David  Belo Horizonte    Belo Horizonte
# 4    Felpe             NaN      Desconhecida
# 5  Roberto          Manaus            Manaus

# %% [markdown]
# proposta:
#
# 1. Crie um DataFrame chamado df_estudantes com as seguintes colunas: "nome", "idade" e "nota".
#
# 2. Insira pelo menos 5 estudantes, mas deixe a nota de alguns deles como nula (use np.nan para representar os valores nulos).
#
# 3. Aplique as técnicas que aprendemos na aula para tratar os dados faltantes na coluna "nota":
# Preencha os valores nulos com a média das notas.
# Depois, crie uma nova coluna chamada "nota_mediana" e preencha os valores nulos com a mediana das notas.
#
# 4. Por fim, exiba o DataFrame original e o DataFrame após o tratamento dos dados.

# %%
df_estudantes = pd.DataFrame(
    {
        'Nome': ['Alice', 'Pedro', 'Charlie', 'David','Felpe'],
        'Idade': [18, 19, 22, 24, 17],
        'Nota': [5,np.nan,8,np.nan,1]
    })
df_estudantes
# Out:
#       Nome  Idade  Nota
# 0    Alice     18   5.0
# 1    Pedro     19   NaN
# 2  Charlie     22   8.0
# 3    David     24   NaN
# 4    Felpe     17   1.0

# %%
df_estudantes['Nota_Media']= df_estudantes['Nota'].fillna(df_estudantes['Nota'].mean().round(2))
df_estudantes['Nota_Mediana']= df_estudantes['Nota'].fillna(df_estudantes['Nota'].median())
df_estudantes
# Out:
#       Nome  Idade  Nota  Nota_Media  Nota_Mediana
# 0    Alice     18   5.0        5.00           5.0
# 1    Pedro     19   NaN        4.67           5.0
# 2  Charlie     22   8.0        8.00           8.0
# 3    David     24   NaN        4.67           5.0
# 4    Felpe     17   1.0        1.00           1.0

# %% [markdown]
# #Visualização de dados

# %% [markdown]
# Palavra chave: MATPLOTLIB

# %%
df_limpo.head()
# Out:
#     ano nivel_experiencia  contrato               cargo  salario moeda  \
# 0  2025            Senior  Integral  Solutions Engineer   214000   USD
# 1  2025            Senior  Integral  Solutions Engineer   136000   USD
# 2  2025             Pleno  Integral       Data Engineer   158800   USD
# 3  2025             Pleno  Integral       Data Engineer   139200   USD
# 4  2025            Junior  Integral       Data Engineer    90000   USD
#
#    salario_dolar residencia      remoto localizacao_empresa tamanho_empresa
# 0         214000         US      Remoto                  US           Media
# 1         136000         US      Remoto                  US           Media
# 2         158800         AU  Presencial                  AU           Media
# 3         139200         AU  Presencial                  AU           Media
# 4          90000         US  Presencial                  US           Media

# %%
#plotando um grafico com as quantidades de de cada nivel de experiencia
df_limpo['nivel_experiencia'].value_counts().plot(kind='bar', title='Distribuição de Cargos por Nível de Experiência')
# Out:
# <Axes: title={'center': 'Distribuição de Cargos por Nível de Experiência'}, xlabel='nivel_experiencia'>

# %%
plt.figure(figsize=(8, 5)) #cria a figura
sns.barplot(x='nivel_experiencia', y='salario_dolar', data=df_limpo) #cria o grafico
plt.xlabel('Nível de Experiência') #nome do eixo x
plt.ylabel('Salário Médio') #nome do eixo Y
plt.title('Distribuição de Salários medio anual (USD)') #titulo do grafico
plt.show() #mostrar figura

# %%
#agrupando por nivel de experiencia o salario medio ordenado do maior para o menor
df_limpo.groupby('nivel_experiencia')['salario_dolar'].mean().sort_values(ascending=False)
# Out:
# nivel_experiencia
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: salario_dolar, dtype: float64

# %%
salario_ordenado = df_limpo.groupby('nivel_experiencia')['salario_dolar'].mean().sort_values(ascending=False).index
salario_ordenado
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Junior'], dtype='object', name='nivel_experiencia')

# %%
plt.figure(figsize=(8, 5)) #cria a figura
sns.barplot(x='nivel_experiencia', y='salario_dolar', data=df_limpo, order=salario_ordenado) #cria o grafico
plt.xlabel('Nível de Experiência') #nome do eixo x
plt.ylabel('Salário Médio') #nome do eixo Y
plt.title('Distribuição de Salários medio anual (USD)') #titulo do grafico
plt.show() #mostrar figura

# %%
plt.figure(figsize=(8, 5)) #cria a figura
sns.histplot(df_limpo['salario_dolar'], bins= 50, kde=True)
plt.xlabel('Salário')
plt.ylabel('Frequência')
plt.title('Distribuição de Salários anuais')
plt.show()

# %% [markdown]
# Neste caso, a maioria dos salarios estão concentrados nos valores mais baixos.

# %%
plt.figure(figsize=(8, 5)) #cria a figura
sns.boxplot(x='salario_dolar', data=df_limpo) #cria o grafico
plt.xlabel('Salario Anual em USD') #nome do eixo x
plt.title('Distribuição de Salários medio anual (USD)') #titulo do grafico
plt.show() #mostrar figura

# %%
ordem_lvl_exp = ['Junior','Pleno','Senior','Executivo']
plt.figure(figsize=(8, 5)) #cria a figura
sns.boxplot(x='nivel_experiencia',y='salario_dolar', data=df_limpo, order=ordem_lvl_exp) #cria boxsplot
plt.xlabel('Nível de Experiência') #nome do eixo x
plt.ylabel('Salário Médio') #nome do eixo Y
plt.title('Distribuição de Salários medio por experiencia') #titulo do grafico
plt.show() #mostrar figura

# %%
ordem_lvl_exp = ['Junior','Pleno','Senior','Executivo']
plt.figure(figsize=(8, 5)) #cria a figura
sns.boxplot(x='nivel_experiencia',y='salario_dolar', data=df_limpo, order=ordem_lvl_exp, palette='Set2', hue='nivel_experiencia') #cria boxsplot
plt.xlabel('Nível de Experiência') #nome do eixo x
plt.ylabel('Salário Médio') #nome do eixo Y
plt.title('Distribuição de Salários medio por experiencia') #titulo do grafico
plt.show() #mostrar figura

# %%
# Calcular a média dos salários por nível de experiência
salario_medio_plotly = df_limpo.groupby('nivel_experiencia')['salario_dolar'].mean().sort_values(ascending=False).reset_index()

# Criar o gráfico de barras interativo com Plotly Express
fig = px.bar(salario_medio_plotly,
             x='nivel_experiencia',
             y='salario_dolar',
             title='Distribuição de Salários médio anual (USD) por Nível de Experiência',
             labels={'nivel_experiencia': 'Nível de Experiência', 'salario_dolar': 'Salário Médio'},
             color='nivel_experiencia', # Adiciona cor por nível de experiência
             template='plotly_white' # Define o template do gráfico
            )

# Exibir o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7026167-002b-4afb-9117-cb86d9465b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7026167-002b-4afb-9117-cb86d9465b69")) {                    Plotly.newPlot(                        "a7026167-002b-4afb-9117-cb86d9465b69",                        [{"alignmentgroup":"True","hovertemplate":"Nível de Experiência=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Executivo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Executivo","offsetgroup":"Executivo","orientation":"v","showlegend":true,"textposition":"auto","x":["Executivo"],"xaxis":"x","y":[202027.6678125],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Nível de Experiência=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Senior","offsetgroup":"Senior","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior"],"xaxis":"x","y":[172850.83830079238],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Nível de Experiência=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pleno","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pleno","offsetgroup":"Pleno","orientation":"v","showlegend":true,"textposition":"auto","x":["Pleno"],"xaxis":"x","y":[143044.8459789432],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Nível de Experiência=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Junior","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Junior","offsetgroup":"Junior","orientation":"v","showlegend":true,"textposition":"auto","x":["Junior"],"xaxis":"x","y":[99034.96326661843],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...

# %%
# Contar o numero de registros por tipo de trabalho
conta_remoto = df_limpo['remoto'].value_counts().reset_index()
#definir o nome das colulas
conta_remoto.columns = ['tipo_trabalho', 'quantidade']
# Criar o gráfico de pizza interativo com Plotly Express
fig = px.pie(conta_remoto,
             values='quantidade',
             names='tipo_trabalho',
             title='Proporção de Tipos de Trabalho Remoto',
             hole=0.5 #define o tamanho do burado (rosca)
            )
fig.update_traces(textinfo='percent+label') #define o texto do gráfico
# Exibir o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c15cb121-98da-4162-84de-81785076b40e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c15cb121-98da-4162-84de-81785076b40e")) {                    Plotly.newPlot(                        "c15cb121-98da-4162-84de-81785076b40e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"tipo_trabalho=%{label}\u003cbr\u003equantidade=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Presencial","Remoto","Híbrido"],"legendgroup":"","name":"","showlegend":true,"values":[105305,27716,318],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marke ...

# %%
df_limpo['cargo'].unique()
# Out:
# array(['Solutions Engineer', 'Data Engineer', 'Data Scientist',
#        'BI Developer', 'Data Analyst', 'Applied Scientist',
#        'Systems Engineer', 'Director', 'Associate', 'Software Engineer',
#        'Consultant', 'Analyst', 'Product Manager', 'Software Developer',
#        'Engineer', 'Developer', 'Data Specialist', 'Manager',
#        'Research Scientist', 'Software Architect',
#        'Data Management Analyst', 'Data Reporter',
#        'Computational Biologist', 'Product Designer',
#        'Software Development Engineer', 'Architect',
#        'Data Analytics Manager', 'Principal Statistical Programmer',
#        'Cloud Engineer', 'Data Architect', 'Product Owner', 'Executive',
#        'Business Intelligence Engineer', 'Data Governance Lead',
#        'Data Governance Specialist', 'AI Engineer', 'Solutions Architect',
#        'AI Researcher', 'Machine Learning Engineer', 'Bear Robotics',
#        'Data Strategist', 'Research Engineer', 'Researcher',
#        'Business Analyst', 'Solution Engineer', 'Full Stack Developer',
#        'Product Analyst', 'Full Stack Engineer', 'Backend Engineer',
#        'Sales Engineer', 'Prompt Engineer', 'Head of AI',
#        'Platform Engineer', 'Analytics Engineer', 'Engineering Manager',
#        'BI Engineer', 'Systems Administrator', 'Data Platform Engineer',
#        'Site Reliability Engineer', 'Computer Vision Engineer',
#        'Data Operations Analyst', 'MLOps Engineer', 'Solution Architect',
#        'Data Product Owner', 'Data Analytics Specialist',
#        'Artificial Intelligence Engineer', 'ML Scientist',
#        'Data Governance Manager', 'Data Manager',
#        'Machine Learning Scientist', 'Data Management', 'Data Lead',
#        'System Engineer', 'Research Assistant', 'Statistical Programmer',
#        'Data Analysis', 'Data Quality Lead', 'Tech Lead', 'Head of Data',
#        'Data Quality Analyst', 'Quantitative Analyst', 'AI Developer',
#        'Business Intelligence Specialist',
#        'Business Intelligence Analyst', 'Data Modeler', 'Analytics Lead',
#        'Business Intelligence Developer', 'Creative Technologist',
#        'Member of Technical Staff', 'Quantitative Researcher',
#        'Data Integration Engineer', 'Data Management Specialist',
#        'Postdoctoral Fellow', 'Power BI Developer',
#        'Data Product Manager', 'Technical Architect', 'Data Governance',
#        'Actuary', 'Big Data Developer', 'Lead Engineer', 'Technical Lead',
#        'Encounter Data Management Professional',
#        'Data and Reporting Professional', 'Cloud Database Engineer',
#        'Tableau Developer', 'Bioinformatics Specialist',
#        'Business Intelligence', 'Research Associate',
#        'Data Analytics Lead', 'AI Specialist',
#        'Data Visualization Specialist', 'Computational Scientist',
#        'Data Developer', 'Data Governance Analyst', 'DevOps Engineer',
#        'Data Governance Engineer', 'AI Architect', 'Data Operations',
#        'Data Integrity Specialist', 'Postdoctoral Researcher',
#        'Statistician', 'Principal Researcher', 'QA Engineer',
#        'Data Operations Lead', 'Quantitative Developer',
#        'Account Executive', 'AI Scientist', 'Data Management Lead',
#        'Machine Learning Specialist', 'AI Content Writer',
#        'Psychometrician', 'Director of Product Management',
#        'Python Developer', 'Product Specialist', 'Automation Engineer',
#        'Decision Scientist', 'AI Governance Specialist', 'Data Steward',
#        'Sales Development Representative', 'Machine Learning Researcher',
#        'AI Research Scientist', 'Insight Analyst',
#        'Data Quality Engineer', 'Data & Analytics Analyst',
#        'Technical Specialist', 'Postdoctoral Research Fellow', 'Power BI',
#        'Director of Machine Learning', 'Bioinformatician',
#        'Principal Scientist', 'AI Data Scientist',
#        'Research Professional', 'Power BI Administrator',
#        'Data Consultant', 'Research Analyst', 'ETL Developer',
#        'Analytics Specialist', 'Economist', 'Cheminformatics Scientist',
#        'Algorithm Developer', 'Data Team Lead', 'Data Analist',
#        'Technical Recruiter', 'Data Governance Consultant',
#        'Web Developer', 'Data Visualization Engineer',
#        'Head of Marketing', 'Technical Support Specialist',
#        'Post Doctoral Fellow', 'Security Researcher', 'AI Lead',
#        'Cientista de Dados', 'AI Tech Lead', 'Bioinformatics Scientist',
#        'Clinical Aide', 'System Administrator',
#        'Data Operations Engineer', 'Data Infrastructure Engineer',
#        'AI Strategist', 'DataOps Engineer', 'Application Developer',
#        'AI Product Lead', 'AI Solutions Specialist',
#        'Enterprise Account Executive', 'Software Development Director',
#        'BI Analyst', 'Advanced Data Analyst', 'Head of Machine Learning',
#        'Cloud Database Administrator', 'AI Engineering Lead',
#        'Data Reporting Specialist', 'Quant Trader', 'Data Strategy Lead',
#        'Copywriter', 'Integration Specialist', 'Database Administrator',
#        'Backend Developer', 'Business Development Representative',
#        'Technical Writer', 'AI Product Owner',
#        'Technical Support Engineer', 'Trainee', 'Head of Applied AI',
#        'Machine Learning Architect', 'Java Developer',
#        'Principal Engineer', 'Business Intelligence Lead',
#        'Data Visualization Developer', 'Data Integration Specialist',
#        'Data Management Associate', 'Power BI Expert',
#        'Marketing Science Partner', 'Data Operations Specialist',
#        'Salesforce Administrator', 'Chatbot Developer', 'Cloud Developer',
#        'Data Analytics Business Partner', 'Data Quality Expert',
#        'Data Integrator', 'Data Operator', 'BI & Data Analyst',
#        'Network Engineer', 'Risk Analyst', 'Data Integration Lead',
#        'DevOps Lead', 'Data Product Lead', 'Cloud Architect',
#        'Data Scientist Manager', 'Robotics Engineer',
#        'Power BI Specialist', 'Data Management Consultant', 'Stage',
#        'Data and Analytics Consultant', 'Alternance', 'Big Data Engineer',
#        'LLM Engineer', 'Quantitative Trader', 'Machine Learning Lead',
#        'Data Integration Developer', 'Data Operations Manager',
#        'Data Archivist', 'Developer Advocate', 'RPA Developer',
#        'Research Team Lead', 'Data Analytics Developer',
#        'Quant Options Trader', 'Data Management Expert',
#        'Conversational AI Designer', 'Scala Spark Developer',
#        'Business Intelligence Manager', 'Data Scientist Expert',
#        'Customer Success Engineer', 'Data Visualization Designer',
#        'Experienced Quantitative Strategist', 'Tech Lead Data',
#        'Data and Reporting Analyst', 'AI Programmer',
#        'Data Analysis Specialist', 'GenAI Architect',
#        'Machine Learning Developer', 'Data Reporting Analyst',
#        'Data Integrity Analyst', 'Data Visualization Analyst',
#        'Lead Data Analysis', 'Data Visualization Expert',
#        'Customer Success Manager', 'Actuarial Analyst',
#        'AI Governance Lead', 'Data Quality Specialist',
#        'AI Data Engineer', 'Technology Integrator',
#        'Principal Software Architect', 'Master Data Management',
#        'Staff Data Scientist', 'AI Machine Learning Engineer',
#        'Lead Analyst', 'Data Analytics Consultant',
#        'Data Scientist Associate', 'Clinical Data Operator',
#        'Research Data Manager', 'Applied Research Scientist',
#        'Lead Data Management', 'Data Integration Analyst',
#        'Safety Data Management Specialist', 'Big Data Analyst',
#        'Pricing Analyst', 'Lead Data Engineer', 'AI Engineering Manager',
#        'Data Management Coordinator', 'Analytics Analyst',
#        'Controls Engineer', 'Machine Learning Tech Lead',
#        'Business Development Manager', 'Business Insights Manager',
#        'Platform Data Engineer',
#        'Principal Application Delivery Consultant',
#        'Data Governance Architect', 'Power BI Consultant',
#        'Backend Software Engineer', 'AI Product Manager',
#        'Data Operations Associate', 'ML Infrastructure Engineer',
#        'Fullstack Engineer', 'Machine Learning Quality Engineer',
#        'Security Engineer', 'Databricks Engineer',
#        'Infrastructure Engineer', 'Machine Learning Performance Engineer',
#        'Data Analytics Associate', 'Power BI Architect',
#        'Machine Learning Platform Engineer', 'AI Solution Architect',
#        'Data Scientist Lead', 'Machine Vision Engineer',
#        'Machine Learning Model Engineer', 'Marketing Analyst',
#        'Data Management Manager', 'Marketing Analytics Manager',
#        'Applied AI ML Lead', 'Data Strategy Manager',
#        'Machine Learning Manager', 'Data Product Analyst',
#        'Data Quality Manager', 'Elasticsearch Administrator',
#        'Machine Learning Infrastructure Engineer', 'People Data Analyst',
#        'Frontend Engineer', 'NLP Engineer', 'SAS Developer',
#        'Data Analytics Team Lead', 'Machine Learning Modeler',
#        'Data Integration Coordinator', 'Admin & Data Analyst',
#        'Head of Business Intelligence', 'ETL Engineer',
#        'AI Research Engineer', 'Business Intelligence Consultant',
#        'Robotics Software Engineer', 'AI Software Engineer',
#        'Lead AI Engineer', 'AI Software Development Engineer',
#        'Master Data Specialist', 'Consultant Data Engineer',
#        'Manager Data Management', 'Director of Business Intelligence',
#        'Lead Data Scientist', 'CRM Data Analyst', 'BI Data Analyst',
#        'Applied Data Scientist', 'Data DevOps Engineer',
#        'Quantitative Research Analyst', 'Lead Machine Learning Engineer',
#        'Machine Learning Research Engineer', 'Data Analyst Lead',
#        'Data Pipeline Engineer', 'Lead Data Analyst',
#        'Business Data Analyst', 'Marketing Data Scientist',
#        'Deep Learning Engineer', 'Financial Data Analyst',
#        'Azure Data Engineer', 'Principal Data Scientist',
#        'Staff Data Analyst', 'Machine Learning Software Engineer',
#        'Applied Machine Learning Scientist',
#        'Principal Machine Learning Engineer', 'Principal Data Engineer',
#        'Staff Machine Learning Engineer',
#        'Business Intelligence Data Analyst', 'Finance Data Analyst',
#        'Software Data Engineer', 'Compliance Data Analyst',
#        'Cloud Data Engineer', 'Analytics Engineering Manager',
#        'AWS Data Architect', 'Product Data Analyst',
#        'Autonomous Vehicle Technician', 'Sales Data Analyst',
#        'Applied Machine Learning Engineer', 'BI Data Engineer',
#        'Deep Learning Researcher', 'Big Data Architect',
#        'Computer Vision Software Engineer', 'Marketing Data Engineer',
#        'Data Science Tech Lead', 'Marketing Data Analyst',
#        'Principal Data Architect', 'Data Analytics Engineer',
#        'Cloud Data Architect', 'Principal Data Analyst'], dtype=object)

# %%
# Dicionario com o nome de todos os paises
country_mapping = {
    'US': 'United States',
    'SG': 'Singapore',
    'BG': 'Bulgaria',
    'CH': 'Switzerland',
    'EG': 'Egypt',
    'CA': 'Canada',
    'MX': 'Mexico',
    'NZ': 'New Zealand',
    'JP': 'Japan',
    'AU': 'Australia',
    'IT': 'Italy',
    'DO': 'Dominican Republic',
    'DZ': 'Algeria',
    'KR': 'South Korea',
    'DE': 'Germany',
    'FR': 'France',
    'IE': 'Ireland',
    'PT': 'Portugal',
    'NO': 'Norway',
    'SE': 'Sweden',
    'GB': 'United Kingdom',
    'UA': 'Ukraine',
    'PH': 'Philippines',
    'BR': 'Brazil',
    'PL': 'Poland',
    'UZ': 'Uzbekistan',
    'NL': 'Netherlands',
    'CL': 'Chile',
    'BE': 'Belgium',
    'RU': 'Russia',
    'HK': 'Hong Kong',
    'CY': 'Cyprus',
    'LT': 'Lithuania',
    'LV': 'Latvia',
    'AD': 'Andorra',
    'AT': 'Austria',
    'NG': 'Nigeria',
    'KE': 'Kenya',
    'ES': 'Spain',
    'TR': 'Turkey',
    'ZA': 'South Africa',
    'FI': 'Finland',
    'IN': 'India',
    'GR': 'Greece',
    'AR': 'Argentina',
    'EE': 'Estonia',
    'RO': 'Romania',
    'SK': 'Slovakia',
    'TH': 'Thailand',
    'RS': 'Serbia',
    'HU': 'Hungary',
    'PK': 'Pakistan',
    'TW': 'Taiwan',
    'EC': 'Ecuador'
}

# %%
#Calcular o salario médio de cientistas de dados por pais
salario_cientista_dados= df_limpo.query('cargo == "Data Scientist"').groupby('residencia')['salario_dolar'].mean().sort_values(ascending=False).reset_index()

# Adicionando uma nova coluna com o nome dos paises
salario_cientista_dados['residencia_full'] = salario_cientista_dados['residencia'].map(country_mapping)

fig = px.bar(salario_cientista_dados,
             x='residencia',
             y='salario_dolar',
             title='Distribuição de Salários médio anual (USD) por país dos cientistas de dados',
             labels={'residencia': 'País', 'salario_dolar': 'Salário Médio'},
             color='residencia', # Adiciona cor por país
             template='plotly_white', # Define o template do gráfico
             hover_name='residencia_full' # Usa o nome completo do pais como legenda
            )

# Exibir o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad315582-3aeb-42bf-9c66-e27809b751db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad315582-3aeb-42bf-9c66-e27809b751db")) {                    Plotly.newPlot(                        "ad315582-3aeb-42bf-9c66-e27809b751db",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United States"],"legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"v","showlegend":true,"textposition":"auto","x":["US"],"xaxis":"x","y":[162802.49460305294],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Singapore"],"legendgroup":"SG","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SG","offsetgroup":"SG","orientation":"v","showlegend":true,"textposition":"auto","x":["SG"],"xaxis":"x","y":[152522.7142857143],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bulgaria"],"legendgroup":"BG","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BG","offsetgroup":"BG","orientation":"v","showlegend":true,"textposition":"auto","x":["BG"],"xaxis":"x","y":[152500.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Switzerland"],"legendgroup":"CH","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"CH","offsetgroup":"CH","orientation":"v","showlegend":true,"textposition":"auto","x":["CH"],"xaxis":"x","y":[152256.66666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Egypt"],"legendgroup":"EG","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"EG","offsetgroup":"EG","orientation":"v","showlegend":true,"textposition":"auto","x":["EG"],"xaxis":"x","y":[140690.9090909091],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Canada"],"legendgroup":"CA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"CA","offsetgroup":"CA","orientation":"v","showlegend":true,"textposition":"auto","x":["CA"],"xaxis":"x","y":[140519.98476190475],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mexico"],"legendgroup":"MX","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"MX","offsetgroup":"MX","orientation":"v","showlegend":true,"textposition":"auto","x":["MX"],"xaxis":"x","y":[140466.66666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePaís=%{x}\u003cbr\u003eSalário Médio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["New Zealand"],"legendgroup":"NZ","marker":{ ...

# %% [markdown]
# 1. Utilize o método groupby para agrupar os dados pela coluna de senioridade.
#
# 2. Calcule a mediana dos salários (USD) para cada nível de senioridade.
#
# 3. Plote um gráfico de barras usando a biblioteca Seaborn ou Matplotlib, mostrando a mediana dos salários por senioridade.
#
# 4. Adicione títulos e rótulos aos eixos para tornar o gráfico mais informativo.

# %%
mediana_salario= df_limpo.groupby('nivel_experiencia')['salario_dolar'].median().sort_values(ascending=False)
plt.figure(figsize=(8, 5)) #cria a figura
sns.barplot(x=mediana_salario.index, y=mediana_salario, palette='viridis') #cria o grafico
plt.xlabel('Nível de Experiência') #nome do eixo x
plt.ylabel('Salário Mediana') #nome do eixo Y
plt.title('Mediana dos Salários anual (USD) por Nível de Experiência') #titulo do grafico
plt.show() #mostrar figura
# Out:
# /tmp/ipython-input-2430492028.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
